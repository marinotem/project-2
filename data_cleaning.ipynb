# %%
#adding in dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# adding homicide file as a csv in pandas
csv_file = "Resources/homicide.csv"
homicide_df = pd.read_csv(csv_file)
homicide_df.head()
# Out:
#    Record ID Agency Code     Agency Name       Agency Type     City    State  \
# 0     594646     FL00100  Alachua County           Sheriff  Alachua  Florida
# 1     594647     FL00100  Alachua County           Sheriff  Alachua  Florida
# 2     594648     FL00100  Alachua County           Sheriff  Alachua  Florida
# 3     594649     FL00100  Alachua County           Sheriff  Alachua  Florida
# 4     594650     FL00101     Gainesville  Municipal Police  Alachua  Florida
#
#    Year      Month  Incident              Crime Type  ... Victim Ethnicity  \
# 0  2012      April       933  Murder or Manslaughter  ...          Unknown
# 1  2012        May       934  Murder or Manslaughter  ...          Unknown
# 2  2012  September       935  Murder or Manslaughter  ...          Unknown
# 3  2012   December       936  Murder or Manslaughter  ...          Unknown
# 4  2012    January       937  Murder or Manslaughter  ...          Unknown
#
#   Perpetrator Sex  Perpetrator Age Perpetrator Race Perpetrator Ethnicity  \
# 0         Unknown                0          Unknown               Unknown
# 1            Male               19            White               Unknown
# 2            Male               48            Black               Unknown
# 3            Male               38            Black               Unknown
# 4            Male               22            White               Unknown
#
#   Relationship        Weapon Victim Count Perpetrator Count Record Source
# 0      Unknown       Firearm            0                 0          FOIA
# 1      Unknown       Handgun            0                 0          FOIA
# 2      Unknown  Blunt Object            0                 0          FOIA
# 3      Unknown       Handgun            0                 0          FOIA
# 4      Unknown         Knife            0                 1          FOIA
#
# [5 rows x 24 columns]

# %%
# cleaning homicide df 
# taking off agency id, agency name, agency type 
homicide_df = homicide_df.drop(columns=["Agency Code", "Agency Name", "Agency Type", "State"])
homicide_df
# Out:
#        Record ID        City  Year      Month  Incident  \
# 0         594646     Alachua  2012      April       933
# 1         594647     Alachua  2012        May       934
# 2         594648     Alachua  2012  September       935
# 3         594649     Alachua  2012   December       936
# 4         594650     Alachua  2012    January       937
# ...          ...         ...   ...        ...       ...
# 43804     638450        Park  2014    January         1
# 43805     638451    Sheridan  2014       June         1
# 43806     638452    Sheridan  2014  September         1
# 43807     638453    Sublette  2014   December         1
# 43808     638454  Sweetwater  2014  September         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter           No       Male          23
# 1      Murder or Manslaughter          Yes       Male          46
# 2      Murder or Manslaughter          Yes     Female          52
# 3      Murder or Manslaughter          Yes       Male          44
# 4      Murder or Manslaughter          Yes       Male          78
# ...                       ...          ...        ...         ...
# 43804  Murder or Manslaughter           No       Male          30
# 43805  Murder or Manslaughter          Yes       Male          62
# 43806  Murder or Manslaughter          Yes     Female           0
# 43807  Murder or Manslaughter          Yes       Male          55
# 43808  Murder or Manslaughter          Yes     Female           0
#
#                   Victim Race Victim Ethnicity Perpetrator Sex  \
# 0                       Black          Unknown         Unknown
# 1                       White          Unknown            Male
# 2                       Black          Unknown            Male
# 3                       Black          Unknown            Male
# 4                       White          Unknown            Male
# ...                       ...              ...             ...
# 43804                   White         Hispanic         Unknown
# 43805                   White          Unknown            Male
# 43806  Asian/Pacific Islander          Unknown          Female
# 43807                   White     Not Hispanic            Male
# 43808                   White     Not Hispanic          Female
#
#       Perpetrator Age        Perpetrator Race Perpetrator Ethnicity  \
# 0                   0                 Unknown               Unknown
# 1                  19                   White               Unknown
# 2                  48                   Black               Unknown
# 3                  38                   Black               Unknown
# 4                  22                   White               Unknown
# ...               ...                     ...                   ...
# 43804               0                 Unknown               Unknown
# 43805              57                   White               Unknown
# 43806              22  Asian/Pacific Islander               Unknown
# 43807              31                   White          Not Hispanic
# 43808              24                   White          Not Hispanic
#
#        Relationship        Weapon  Victim Count  Perpetrator Count  \
# 0           Unknown       Firearm             0                  0
# 1           Unknown       Handgun             0                  0
# 2           Unknown  Blunt Object             0                  0
# 3           Unknown       Handgun             0                  0
# 4           Unknown         Knife             0                  1
# ...             ...           ...           ...                ...
# 43804       Unknown       Handgun             0                  0
# 43805  Acquaintance       Handgun             0                  0
# 43806      Daughter   Suffocation             0                  0
# 43807      Stranger         Knife             0                  1
# 43808      Daughter  Blunt Object             0                  1
#
#       Record Source
# 0              FOIA
# 1              FOIA
# 2              FOIA
# 3              FOIA
# 4              FOIA
# ...             ...
# 43804           FBI
# 43805           FBI
# 43806           FBI
# 43807           FBI
# 43808           FBI
#
# [43809 rows x 20 columns]

# %%
# cleaning out only for cities that are in our weather datasets
homicide_clean_df = homicide_df[homicide_df['City'].isin(['Portland','San Francisco','Seattle','Los Angeles','San Diego','Las Vegas','Phoenix','Albuquerque','Denver','San Antonio','Dallas','Houston','Kansas City','Minneapolis','Saint Louis','Chicago','Nashville','Indianapolis','Atlanta','Detroit','Jacksonville','Charlotte','Miami','Pittsburgh','Toronto','Philadelphia','New York','Boston'])]
homicide_clean_df
# Out:
#        Record ID           City  Year     Month  Incident  \
# 140       594786      Charlotte  2012      July        73
# 141       594787      Charlotte  2012       May        74
# 1867      596513  San Francisco  2013   January         1
# 2101      596747    Los Angeles  2013       May         1
# 2102      596748    Los Angeles  2013      July         3
# ...          ...            ...   ...       ...       ...
# 42521     637167         Dallas  2014  December        10
# 42522     637168         Dallas  2014  December        11
# 42523     637169         Dallas  2014  December        12
# 42524     637170         Dallas  2014  December        13
# 42525     637171         Dallas  2014  December        14
#
#                    Crime Type Crime Solved Victim Sex  Victim Age Victim Race  \
# 140    Murder or Manslaughter          Yes       Male           1       White
# 141    Murder or Manslaughter          Yes       Male          74       White
# 1867   Murder or Manslaughter           No       Male          50       Black
# 2101   Murder or Manslaughter          Yes     Female          80       White
# 2102   Murder or Manslaughter           No       Male          30       Black
# ...                       ...          ...        ...         ...         ...
# 42521  Murder or Manslaughter          Yes     Female          34       White
# 42522  Murder or Manslaughter           No     Female          54       Black
# 42523  Murder or Manslaughter           No       Male          32       Black
# 42524  Murder or Manslaughter          Yes       Male          20       White
# 42525  Murder or Manslaughter          Yes       Male          82       Black
#
#       Victim Ethnicity Perpetrator Sex Perpetrator Age Perpetrator Race  \
# 140            Unknown          Female              29            White
# 141            Unknown            Male              48            White
# 1867           Unknown         Unknown               0          Unknown
# 2101      Not Hispanic            Male              84            White
# 2102      Not Hispanic         Unknown               0          Unknown
# ...                ...             ...             ...              ...
# 42521         Hispanic            Male              36            White
# 42522     Not Hispanic         Unknown               0          Unknown
# 42523     Not Hispanic         Unknown               0          Unknown
# 42524         Hispanic            Male              21            Black
# 42525     Not Hispanic          Female              82            Black
#
#       Perpetrator Ethnicity  Relationship        Weapon  Victim Count  \
# 140                 Unknown           Son       Unknown             0
# 141                 Unknown       Unknown  Blunt Object             0
# 1867                Unknown       Unknown       Unknown             0
# 2101           Not Hispanic        Family       Shotgun             1
# 2102                Unknown       Unknown       Handgun             1
# ...                     ...           ...           ...           ...
# 42521              Hispanic    Girlfriend         Knife             0
# 42522               Unknown       Unknown  Blunt Object             0
# 42523               Unknown       Unknown       Handgun             0
# 42524          Not Hispanic  Acquaintance       Handgun             0
# 42525          Not Hispanic       Husband  Blunt Object             0
#
#        Perpetrator Count Record Source
# 140                    1          FOIA
# 141                    0          FOIA
# 1867                   0           FBI
# 2101                   0           FBI
# 2102                   0           FBI
# ...                  ...           ...
# 42521                  0           FBI
# 42522                  0           FBI
# 42523                  0           FBI
# 42524                  1           FBI
# 42525                  0           FBI
#
# [4999 rows x 20 columns]

# %%
#using group by to aggregate homicides by month for each city
homicide_cleaner_df = homicide_clean_df.groupby(['City','Year','Month'],as_index=False)['Record ID'].agg('count')
homicide_cleaner_df
# Out:
#               City  Year      Month  Record ID
# 0        Charlotte  2012       July          1
# 1        Charlotte  2012        May          2
# 2        Charlotte  2013     August          1
# 3        Charlotte  2013   December          1
# 4        Charlotte  2013   November          1
# ..             ...   ...        ...        ...
# 271  San Francisco  2014      March          3
# 272  San Francisco  2014        May          4
# 273  San Francisco  2014   November         10
# 274  San Francisco  2014    October          4
# 275  San Francisco  2014  September          3
#
# [276 rows x 4 columns]

# %%
# import temp csv as df 
csv_file = "Resources/temperature.csv"
temp_df = pd.read_csv(csv_file)
temp_df.head()
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1    285.630000  288.220000  285.830000  287.170000  307.590000
# 2    285.663208  288.247676  285.834650  287.186092  307.590000
# 3    285.756824  288.326940  285.847790  287.231672  307.391513
# 4    285.850440  288.406203  285.860929  287.277251  307.145200
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 0                NaN  309.100000    NaN        NaN        NaN
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
# 4         304.238015  310.327308  304.4      304.4      303.5
#
# [5 rows x 37 columns]

# %%
# import humdiity csv as df 
csv_file = "Resources/humidity.csv"
humidity_df = pd.read_csv(csv_file)
humidity_df.head()
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  Philadelphia  \
# 0          NaN        NaN        NaN      NaN          NaN  ...           NaN
# 1         88.0       82.0       22.0     23.0         50.0  ...          71.0
# 2         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 3         88.0       81.0       21.0     23.0         49.0  ...          70.0
# 4         88.0       81.0       21.0     23.0         49.0  ...          69.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# 0       NaN       NaN     NaN        NaN                NaN   25.0    NaN
# 1      58.0      93.0    68.0       50.0               63.0   22.0   51.0
# 2      57.0      91.0    68.0       51.0               62.0   22.0   51.0
# 3      57.0      87.0    68.0       51.0               62.0   22.0   51.0
# 4      57.0      84.0    68.0       52.0               62.0   22.0   51.0
#
#    Nahariyya  Jerusalem
# 0        NaN        NaN
# 1       51.0       50.0
# 2       51.0       50.0
# 3       51.0       50.0
# 4       51.0       50.0
#
# [5 rows x 37 columns]

# %%
# import weather event csv as df 
csv_file = "Resources/weather_description.csv"
weather_event_df = pd.read_csv(csv_file)
weather_event_df.head()
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# 0           NaN  ...            NaN         NaN              NaN
# 1  sky is clear  ...  broken clouds  few clouds  overcast clouds
# 2  sky is clear  ...  broken clouds  few clouds     sky is clear
# 3  sky is clear  ...  broken clouds  few clouds     sky is clear
# 4  sky is clear  ...  broken clouds  few clouds     sky is clear
#
#          Boston        Beersheba Tel Aviv District          Eilat  \
# 0           NaN              NaN               NaN           haze
# 1  sky is clear     sky is clear      sky is clear           haze
# 2    few clouds     sky is clear      sky is clear  broken clouds
# 3    few clouds  overcast clouds      sky is clear  broken clouds
# 4    few clouds  overcast clouds      sky is clear  broken clouds
#
#              Haifa        Nahariyya        Jerusalem
# 0              NaN              NaN              NaN
# 1     sky is clear     sky is clear     sky is clear
# 2  overcast clouds     sky is clear  overcast clouds
# 3  overcast clouds  overcast clouds  overcast clouds
# 4  overcast clouds  overcast clouds  overcast clouds
#
# [5 rows x 37 columns]

# %%
#drop nans from each df 
temp_clean_df = temp_df.dropna()
humidity_clean_df = humidity_df.dropna()
weather_event_clean_df = weather_event_df.dropna()

temp_clean_df
# Out:
#                   datetime   Vancouver    Portland  San Francisco     Seattle  \
# 1      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# 5      2012-10-01 17:00:00  284.622911  282.109095     289.431869  281.775065
# ...                    ...         ...         ...            ...         ...
# 44456  2017-10-27 20:00:00  286.440000  293.840000     297.060000  286.150000
# 44457  2017-10-27 21:00:00  287.870000  294.850000     299.140000  288.140000
# 44458  2017-10-27 22:00:00  288.420000  295.570000     300.560000  289.440000
# 44459  2017-10-27 23:00:00  288.650000  294.990000     301.060000  290.590000
# 44460  2017-10-28 00:00:00  288.010000  294.520000     302.070000  290.920000
#
#        Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 1       291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2       291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3       291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4       291.857503  291.553209  293.381213  296.654466   285.313345  ...
# 5       291.852162  291.563063  293.370249  296.677445   285.392738  ...
# ...            ...         ...         ...         ...          ...  ...
# 44456   299.990000  299.390000  298.430000  302.150000   284.370000  ...
# 44457   301.320000  299.700000  299.430000  303.650000   285.890000  ...
# 44458   301.600000  300.160000  300.560000  304.480000   286.400000  ...
# 44459   301.760000  300.770000  300.810000  304.950000   286.890000  ...
# 44460   301.520000  300.310000  300.800000  304.950000   286.130000  ...
#
#        Philadelphia    New York    Montreal      Boston   Beersheba  \
# 1        285.630000  288.220000  285.830000  287.170000  307.590000
# 2        285.663208  288.247676  285.834650  287.186092  307.590000
# 3        285.756824  288.326940  285.847790  287.231672  307.391513
# 4        285.850440  288.406203  285.860929  287.277251  307.145200
# 5        285.944057  288.485467  285.874069  287.322831  306.898887
# ...             ...         ...         ...         ...         ...
# 44456    290.600000  289.980000  283.120000  289.740000  287.578000
# 44457    290.330000  289.480000  283.120000  289.080000  287.578000
# 44458    288.490000  287.920000  282.120000  288.090000  287.578000
# 44459    286.160000  285.830000  281.770000  284.940000  285.944000
# 44460    284.880000  284.980000  280.100000  283.010000  285.944000
#
#        Tel Aviv District       Eilat    Haifa  Nahariyya  Jerusalem
# 1             305.470000  310.580000  304.400    304.400     303.50
# 2             304.310000  310.495769  304.400    304.400     303.50
# 3             304.281841  310.411538  304.400    304.400     303.50
# 4             304.238015  310.327308  304.400    304.400     303.50
# 5             304.194188  310.243077  304.400    304.400     303.50
# ...                  ...         ...      ...        ...        ...
# 44456         295.710000  297.150000  299.553    299.553     295.76
# 44457         293.150000  298.150000  299.553    299.553     293.15
# 44458         294.150000  297.150000  299.553    299.553     294.15
# 44459         294.150000  291.019000  299.369    299.369     294.15
# 44460         294.150000  291.019000  299.369    299.369     294.15
#
# [44430 rows x 37 columns]

# %%
temp_cleanest_df = temp_clean_df.melt(id_vars="datetime")
temp_cleanest_df
# Out:
#                     datetime   variable       value
# 0        2012-10-01 13:00:00  Vancouver  284.630000
# 1        2012-10-01 14:00:00  Vancouver  284.629041
# 2        2012-10-01 15:00:00  Vancouver  284.626998
# 3        2012-10-01 16:00:00  Vancouver  284.624955
# 4        2012-10-01 17:00:00  Vancouver  284.622911
# ...                      ...        ...         ...
# 1599475  2017-10-27 20:00:00  Jerusalem  295.760000
# 1599476  2017-10-27 21:00:00  Jerusalem  293.150000
# 1599477  2017-10-27 22:00:00  Jerusalem  294.150000
# 1599478  2017-10-27 23:00:00  Jerusalem  294.150000
# 1599479  2017-10-28 00:00:00  Jerusalem  294.150000
#
# [1599480 rows x 3 columns]

# %%
humidity_clean_df = humidity_clean_df.melt(id_vars="datetime", 
        var_name="City", 
        value_name="Humidity")

# %%
weather_event_clean_df = weather_event_clean_df.melt(id_vars="datetime", 
        var_name="City", 
        value_name="Weather Event")  
weather_event_clean_df
# Out:
#                     datetime       City  Weather Event
# 0        2012-10-01 13:00:00  Vancouver           mist
# 1        2012-10-01 14:00:00  Vancouver  broken clouds
# 2        2012-10-01 15:00:00  Vancouver  broken clouds
# 3        2012-10-01 16:00:00  Vancouver  broken clouds
# 4        2012-10-01 17:00:00  Vancouver  broken clouds
# ...                      ...        ...            ...
# 1600555  2017-10-27 20:00:00  Jerusalem   sky is clear
# 1600556  2017-10-27 21:00:00  Jerusalem   sky is clear
# 1600557  2017-10-27 22:00:00  Jerusalem   sky is clear
# 1600558  2017-10-27 23:00:00  Jerusalem   sky is clear
# 1600559  2017-10-28 00:00:00  Jerusalem     few clouds
#
# [1600560 rows x 3 columns]

# %%
# separating out month and year from datetime
temp_cleanest_df['month'] = temp_cleanest_df["datetime"].str[5:7]
temp_cleanest_df['year'] =temp_cleanest_df["datetime"].str[0:4]

weather_event_clean_df['month'] = weather_event_clean_df["datetime"].str[5:7]
weather_event_clean_df['year'] = weather_event_clean_df["datetime"].str[0:4]

humidity_clean_df['month'] = humidity_clean_df["datetime"].str[5:7]
humidity_clean_df['year'] = humidity_clean_df["datetime"].str[0:4]

# %%
import calendar
temp_cleanest_df
# Out:
#                     datetime   variable       value month  year
# 0        2012-10-01 13:00:00  Vancouver  284.630000    10  2012
# 1        2012-10-01 14:00:00  Vancouver  284.629041    10  2012
# 2        2012-10-01 15:00:00  Vancouver  284.626998    10  2012
# 3        2012-10-01 16:00:00  Vancouver  284.624955    10  2012
# 4        2012-10-01 17:00:00  Vancouver  284.622911    10  2012
# ...                      ...        ...         ...   ...   ...
# 1599475  2017-10-27 20:00:00  Jerusalem  295.760000    10  2017
# 1599476  2017-10-27 21:00:00  Jerusalem  293.150000    10  2017
# 1599477  2017-10-27 22:00:00  Jerusalem  294.150000    10  2017
# 1599478  2017-10-27 23:00:00  Jerusalem  294.150000    10  2017
# 1599479  2017-10-28 00:00:00  Jerusalem  294.150000    10  2017
#
# [1599480 rows x 5 columns]

# %%
temp_cleanest_df['month'] = pd.to_datetime(temp_cleanest_df['month'], format='%m').dt.month_name()

humidity_clean_df['month'] = pd.to_datetime(humidity_clean_df['month'], format='%m').dt.month_name()

weather_event_clean_df['month'] = pd.to_datetime(weather_event_clean_df['month'], format='%m').dt.month_name()

# %%
temp_cleanest_df["year"] = pd.to_numeric(temp_cleanest_df["year"])
humidity_clean_df["year"] = pd.to_numeric(humidity_clean_df["year"])
weather_event_clean_df["year"] = pd.to_numeric(weather_event_clean_df["year"])
# Out:
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
temp_cleanest_df =temp_cleanest_df.loc[temp_cleanest_df["year"] <= 2014 ]
humidity_clean_df = humidity_clean_df.loc[humidity_clean_df["year"] <= 2014 ]
weather_event_clean_df = weather_event_clean_df .loc[weather_event_clean_df["year"] <= 2014 ]
humidity_clean_df
# Out:
#                     datetime       City  Humidity     month  year
# 0        2012-10-01 13:00:00  Vancouver      76.0   October  2012
# 1        2012-10-01 14:00:00  Vancouver      76.0   October  2012
# 2        2012-10-01 15:00:00  Vancouver      76.0   October  2012
# 3        2012-10-01 16:00:00  Vancouver      77.0   October  2012
# 4        2012-10-01 17:00:00  Vancouver      78.0   October  2012
# ...                      ...        ...       ...       ...   ...
# 1281591  2014-12-31 19:00:00  Jerusalem      94.0  December  2014
# 1281592  2014-12-31 20:00:00  Jerusalem      95.0  December  2014
# 1281593  2014-12-31 21:00:00  Jerusalem      95.0  December  2014
# 1281594  2014-12-31 22:00:00  Jerusalem      95.0  December  2014
# 1281595  2014-12-31 23:00:00  Jerusalem      96.0  December  2014
#
# [446076 rows x 5 columns]

# %%
temp_cleanest_df.rename(columns = {'variable':'City', 'value':'Temperature', 'month': 'Month', 'year':'Year'}, inplace = True)
humidity_clean_df.rename(columns = {'month': 'Month', 'year':'Year'}, inplace = True)
weather_event_clean_df.rename(columns = {'month': 'Month', 'year':'Year', 'Weather Event': "Most Common Weather Event"}, inplace = True)
# Out:
#             City      Month  Year Most Common Weather Event
# 0    Albuquerque      April  2013              sky is clear
# 1    Albuquerque      April  2014             broken clouds
# 2    Albuquerque     August  2013              sky is clear
# 3    Albuquerque     August  2014              sky is clear
# 4    Albuquerque   December  2012              sky is clear
# ..           ...        ...   ...                       ...
# 967    Vancouver    October  2012              sky is clear
# 968    Vancouver    October  2013              sky is clear
# 969    Vancouver    October  2014           overcast clouds
# 970    Vancouver  September  2013              sky is clear
# 971    Vancouver  September  2014              sky is clear
#
# [972 rows x 4 columns]

# %%
temp_cleanest_df = temp_cleanest_df.groupby(['City','month', 'year'],as_index=False)['Temperature'].median()
humidity_clean_df = humidity_clean_df.groupby(['City','month', 'year'],as_index=False)['Humidity'].median()

# %%
weather_event_clean_df = weather_event_clean_df.groupby(['City','month', 'year'],as_index=False)['Weather Event'].agg(pd.Series.mode)
weather_event_clean_df
# Out:
#             City      month  year    Weather Event
# 0    Albuquerque      April  2013     sky is clear
# 1    Albuquerque      April  2014    broken clouds
# 2    Albuquerque     August  2013     sky is clear
# 3    Albuquerque     August  2014     sky is clear
# 4    Albuquerque   December  2012     sky is clear
# ..           ...        ...   ...              ...
# 967    Vancouver    October  2012     sky is clear
# 968    Vancouver    October  2013     sky is clear
# 969    Vancouver    October  2014  overcast clouds
# 970    Vancouver  September  2013     sky is clear
# 971    Vancouver  September  2014     sky is clear
#
# [972 rows x 4 columns]

# %%
# homicide_weather_df = pd.merge(pd.merge(homicide_cleaner_df, temp_cleanest_df,on=['City','Month', 'Year']),weather_event_clean_df,on=['City','Month', 'Year'],humidity_clean_df,on=['City','Month', 'Year'])
homicide_weather_df = pd.merge(homicide_cleaner_df, temp_cleanest_df, on=['City','Month', 'Year']).merge(humidity_clean_df, on=['City','Month', 'Year']).merge(weather_event_clean_df, on=['City','Month', 'Year'])
homicide_weather_df
# Out:
#               City  Year      Month  Record ID  Temperature  Humidity  \
# 0        Charlotte  2013     August          1   296.106250      86.0
# 1        Charlotte  2013   December          1   280.370000      63.0
# 2        Charlotte  2013   November          1   282.070000      63.0
# 3        Charlotte  2014    October          1   289.924500      76.0
# 4        Charlotte  2014  September          1   294.426667      88.0
# ..             ...   ...        ...        ...          ...       ...
# 200  San Francisco  2014      March          3   286.700000      81.5
# 201  San Francisco  2014        May          4   288.605250      76.0
# 202  San Francisco  2014   November         10   286.320333      95.0
# 203  San Francisco  2014    October          4   289.305333      86.0
# 204  San Francisco  2014  September          3   290.181750      89.0
#
#     Most Common Weather Event
# 0                sky is clear
# 1                sky is clear
# 2                sky is clear
# 3                sky is clear
# 4                  light rain
# ..                        ...
# 200             broken clouds
# 201              sky is clear
# 202              sky is clear
# 203              sky is clear
# 204              sky is clear
#
# [205 rows x 7 columns]

# %%
# convert Temperature column from Kelvin to Fahrenheit
homicide_weather_df["Temperature (F)"] = (homicide_weather_df["Temperature"]  - 273.15) * (9 / 5) + 32
homicide_weather_df
# Out:
#               City  Year      Month  Record ID  Temperature  Humidity  \
# 0        Charlotte  2013     August          1   296.106250      86.0
# 1        Charlotte  2013   December          1   280.370000      63.0
# 2        Charlotte  2013   November          1   282.070000      63.0
# 3        Charlotte  2014    October          1   289.924500      76.0
# 4        Charlotte  2014  September          1   294.426667      88.0
# ..             ...   ...        ...        ...          ...       ...
# 200  San Francisco  2014      March          3   286.700000      81.5
# 201  San Francisco  2014        May          4   288.605250      76.0
# 202  San Francisco  2014   November         10   286.320333      95.0
# 203  San Francisco  2014    October          4   289.305333      86.0
# 204  San Francisco  2014  September          3   290.181750      89.0
#
#     Most Common Weather Event  Temperature (F)
# 0                sky is clear         73.32125
# 1                sky is clear         44.99600
# 2                sky is clear         48.05600
# 3                sky is clear         62.19410
# 4                  light rain         70.29800
# ..                        ...              ...
# 200             broken clouds         56.39000
# 201              sky is clear         59.81945
# 202              sky is clear         55.70660
# 203              sky is clear         61.07960
# 204              sky is clear         62.65715
#
# [205 rows x 8 columns]

# %%
#drop extra temperature column now that we converted kelvin to fahrenheit
homicide_weather_df = homicide_weather_df.drop(columns=["Temperature"])
homicide_weather_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27796\2188268983.py in <module>
# ----> 1 homicide_weather_df = homicide_weather_df.drop(columns=["Temperature"])
#       2 homicide_weather_df.dtypes
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Temperature'] not found in axis"

# %%
homicide_weather_df.dtypes
# Out:
# City                          object
# Year                           int64
# Month                         object
# Record ID                      int64
# Humidity                     float64
# Most Common Weather Event     object
# Temperature (F)              float64
# dtype: object

# %%
#Connection to database
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5433
database_name = 'homicide_weather_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
engine.table_names()
# Out:
# ['homicide_weather']

# %%
homicide_weather_df.to_sql(name='homicide_weather', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27796\3499551437.py in <module>
# ----> 1 homicide_weather_df.to_sql(name='homicide_weather', con=engine, if_exists='append', index=False)
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1018             )
#    1019         else:
# -> 1020             return meth(self, multiparams, params)
#    1021
#    1022     def _execute_function(self, func, multiparams, params):
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1137             distilled_params,
#    1138             compiled_sql,
# -> 1139             distilled_params,
#    1140         )
#    1141         if self._has_events or self.engine._has_events:
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1519                 )
#    1520             else:
# -> 1521                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1522
#    1523         finally:
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1262                 if not evt_handled:
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#    1266             elif not parameters and context.no_parameters:
#
# c:\Users\marin\anaconda3\envs\PythonDataOne\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# KeyError: 'Temperature (F'
